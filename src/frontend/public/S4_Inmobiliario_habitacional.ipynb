# %% [markdown]
# # Section 4: Inmobiliario y Habitacionales

# %%
# Import Functions to create Json and images
from header_fun import *

# Naming Functions
def naming_image(x):
    return global_dir + "/img/" + init_data_name + x + '.png'

def naming_file(y):
    return global_dir + "/" + init_data_name + y + '.json'   

## Reading Data from API 
file = 'Inmobiliarios_Habitacionales.xlsx'
global_dir = "./data"
norm = False  # no normalizada
init_data_name="IH_"
link_data = "https://smartdata-demo.sfo2.digitaloceanspaces.com/data/Inmobiliarios_Habitacionales.xlsx"
link_img = "https://smartdata-demo.sfo2.digitaloceanspaces.com/data/img/"
link_glosario="https://smartdata-demo.sfo2.digitaloceanspaces.com/data/"
info_header=[ {"titulo":None,"Fuente":None, "LinkDatosOriginales":None, 
               "comment":None, "linkPlot":None,"glosario":None}]

# %% [markdown]
# ## Processing Data

# %% [markdown]
# ### 1) IH_01_Perm_Edif_m2.json

# %%
sheetname = 'Perm_Edif'
full_file_name = '01_Perm_Edif_m2'
info_header[0]["titulo"]= 'Permiso de Edificación m2 por mes y tipo de edificación'
info_header[0]["Fuente"]="CChC - INE"
info_header[0]["LinkDatosOriginales"]=link_data
info_header[0]["comment"]="Permiso de Edificación. A partir del año 2009 están agregados los permisos de edificación las regiones XIV y XV. Fuentes CChC e INE"
info_header[0]["linkPlot"] = link_img + init_data_name + full_file_name + ".png"
info_header[0]["glosario"]= ""

if sheetname=='Perm_Edif':
    df = pd.read_excel( file, sheet_name = sheetname )
    varible_v=["Total pais",
                "I",
                "II",
                "III",
                "IV",
                "V",
                "VI",
                "VII",
                "VIII",
                "IX",
                "X",
                "XI",
                "XII",
                "RM",
                "XIV",
                "XV"]
    variable_meaning=["Total pais",
                "I",
                "II",
                "III",
                "IV",
                "V",
                "VI",
                "VII",
                "VIII",
                "IX",
                "X",
                "XI",
                "XII",
                "RM",
                "XIV",
                "XV"]
    reg_name=["Total pais",
                "I",
                "II",
                "III",
                "IV",
                "V",
                "VI",
                "VII",
                "VIII",
                "IX",
                "X",
                "XI",
                "XII",
                "RM",
                "XIV",
                "XV"]
    toolTip_v=[
                ["Var Total pais",	"I, C y EF- Total país",	"Vvda-R:Total país",	"Serv.-R:Total país"],
                ["Var I",	"I, C y EF-R:I",	"Vvda-R:I",	"Serv.-R:I"],
                ["Var II",	"I, C y EF-R:II",	"Vvda-R:II",	"Serv.-R:II"],
                ["Var III",	"I, C y EF-R:III",	"Vvda-R:III",	"Serv.-R:III"],
                ["Var IV",	"I, C y EF-R:IV",	"Vvda-R:IV",	"Serv.-R:IV"],
                ["Var V",	"I, C y EF-R:V",	"Vvda-R:V",	"Serv.-R:V"],
                ["Var VI",	"I, C y EF-R:VI",	"Vvda-R:VI",	"Serv.-R:VI"],
                ["Var VII",	"I, C y EF-R:VII",	"Vvda-R:VII",	"Serv.-R:VII"],
                ["Var VIII",	"I, C y EF-R:VIII",	"Vvda-R:VIII",	"Serv.-R:VIII"],
                ["Var IX",	"I, C y EF-R:IX",	"Vvda-R:IX",	"Serv.-R:IX"],
                ["Var X",	"I, C y EF-R:X",	"Vvda-R:X",	"Serv.-R:X"],
                ["Var XI",	"I, C y EF-R:XI",	"Vvda-R:XI",	"Serv.-R:XI"],
                ["Var XII",	"I, C y EF-R:XII",	"Vvda-R:XII",	"Serv.-R:XII"],
                ["Var RM",	"I, C y EF-R:RM",	"Vvda-R:RM",	"Serv.-R:RM"],
                ["Var XIV",	"I, C y EF-R:XIV",	"Vvda-R:XIV",	"Serv.-R:XIV"],
                ["Var XV",	"I, C y EF-R:XV",	"Vvda-R:XV",	"Serv.-R:XV"]
              ]

    toolTip_mening=[
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."],
        ["Var Mes","I, C y EF","Vvda","Serv."]
    ]
                                      
    jsonDir = DataToJson(df, varible_v, variable_meaning,reg_name, toolTip_v, toolTip_mening, norm)
    jsonDir = [info_header, jsonDir]
    jsonUTF8 = json.dumps(jsonDir, ensure_ascii=False).encode('utf8')
    jsonUTF8 = json.loads(jsonUTF8)    
    create_image(df, varible_v[0], variable_meaning[0],naming_image(full_file_name))
    name_file = naming_file(full_file_name)
    with open(name_file , 'w') as outfile:  
        json.dump(jsonUTF8, outfile,ensure_ascii=False)
    print("CREATED: ", name_file)
# Out:
# set: None
# CREATED:  ./data/IH_01_Perm_Edif_m2.json

# %% [markdown]
# ### 2) IH_02_Perm_Edif_vvda.json

# %%
sheetname = 'Perm. Edif. Vvda y M2'
full_file_name = '02_Perm_Edif_vvda'
info_header[0]["titulo"]="Permiso de Edificación de Vivienda por tipo de obra y m2"
info_header[0]["Fuente"]="CCHC"
info_header[0]["LinkDatosOriginales"]=link_data
info_header[0]["comment"]="Permiso de Edificación de Vivienda # y m2 por mes, por tipo de obra Habitacional (Vivienda nueva – Ampliación) . Fuentes CChC e INE"
info_header[0]["linkPlot"] = link_img + init_data_name + full_file_name + ".png"
info_header[0]["glosario"]=""

if sheetname=='Perm. Edif. Vvda y M2':
    df = pd.read_excel( file, sheet_name = sheetname )
    data=[["Total Nº",
           "Permisos Viviendas nuevas Nº","Permisos Viviendas Ampliaciones Nº", 
           "m2 Habitacional Viviendas nuevas", "m2 Habitacional Ampliaciones"]]
    dataCorto=[["Permisos No.","Vvdas. Nuevas.", "Vvdas. Ampl.", "Vvdas Nuevas m2",
                "Vvdas Ampl. m2"]]
    
    for index,lista in enumerate(data):
        toolTip_v=[[]]
        toolTip_mening=[[]]
        reg_name=["PAIS"]
        for index2,varname in enumerate(lista):
            if index2==0:
                varible_v=[varname ]
                variable_meaning=[dataCorto[index][index2]]
            else:
                toolTip_v[0].append(varname)
                toolTip_mening[0].append(dataCorto[index][index2])
                
    jsonDir = DataToJson(df,varible_v,variable_meaning,reg_name, toolTip_v, toolTip_mening,norm)
    jsonDir = [info_header,jsonDir ]
    jsonUTF8 = json.dumps(jsonDir, ensure_ascii=False).encode('utf8')
    jsonUTF8 = json.loads(jsonUTF8)    
    create_image(df, varible_v[0], variable_meaning[0],naming_image(full_file_name))
    name_file = naming_file(full_file_name)
    with open(name_file , 'w') as outfile:  
        json.dump(jsonUTF8, outfile,ensure_ascii=False)
    print("CREATED: ", name_file)
# Out:
# set: None
# CREATED:  ./data/IH_02_Perm_Edif_vvda.json

# %% [markdown]
# ### 3) IH_03_venta_viv.json

# %%
sheetname = 'Ventas total sector'
full_file_name = '03_venta_viv'
info_header[0]["titulo"]="Velocidad de venta, mensual"
info_header[0]["Fuente"]="CCHC"
info_header[0]["LinkDatosOriginales"]=link_data
info_header[0]["comment"]="La velocidad de ventas que se calcula como el cociente entre el stock disponible en un mes concreto y las unidades vendidas en ese mismo mes. Fuente CChC"
info_header[0]["linkPlot"] = link_img + init_data_name + full_file_name + ".png"
info_header[0]["glosario"]= ""

if sheetname=='Ventas total sector':
    df = pd.read_excel( file, sheet_name = sheetname)
    varible_v=["Vel venta total meses",
    "Vel venta depto meses",
    "Vel venta casas meses"]
    variable_meaning=["Velocidad Total",
    "Velocidad Deptos",
    "Velocidad Casas"]
    reg_name=["Velocidad Total",
    "Velocidad Deptos",
    "Velocidad Casas"]
    toolTip_v=[["Var_mes"],["Var_mes_depto"],["Var_mes_casas"]]
    toolTip_mening=[["Var Mes"],["Var Mes"],["Var Mes"]]

    jsonDir = DataToJson(df,varible_v,variable_meaning,reg_name, toolTip_v, toolTip_mening)
    jsonDir = [info_header,jsonDir]
    jsonUTF8 = json.dumps(jsonDir, ensure_ascii=False).encode('utf8')
    jsonUTF8 = json.loads(jsonUTF8)    
    create_image(df, varible_v[0], variable_meaning[0],naming_image(full_file_name))
    name_file = naming_file(full_file_name)
    with open(name_file , 'w') as outfile:  
        json.dump(jsonUTF8, outfile,ensure_ascii=False)
    print("CREATED: ", name_file)
# Out:
# set: None
# CREATED:  ./data/IH_03_venta_viv.json

# %% [markdown]
# ### 4) IH_04_venta_stgo.json

# %%
sheetname = 'Ventas Stgo'
full_file_name = '04_venta_stgo'
info_header[0]["titulo"]="Ventas, stock de viviendas y velocidad de venta Santiago, mensual"
info_header[0]["Fuente"]="CCHC"
info_header[0]["LinkDatosOriginales"]=link_data
info_header[0]["comment"]="Se consideran las unidades vendidas mensualmente (departamentos y casas) en Santiago. La velocidad de ventas que se calcula como el cociente entre el stock disponible en un mes concreto y las unidades vendidas en ese mismo mes. Fuente CChC"
info_header[0]["linkPlot"] = link_img + init_data_name + full_file_name + ".png"
info_header[0]["glosario"]= ""

if sheetname=='Ventas Stgo':
    df = pd.read_excel( file, sheet_name = sheetname)
    varible_v=["Total Miles UF",
    "Deptos Miles UF",
    "Casas Miles UF"]
    variable_meaning=[
    "Total Miles UF",
    "Deptos Miles UF",
    "Casas Miles UF"]
    reg_name=["Total Miles UF",
    "Deptos Miles UF",
    "Casas Miles UF"]
    toolTip_v=[
        ["var_Total Miles UF","Total Stock","Total Ventas","Vel venta total meses"],
        ["var_Deptos Miles UF","Depto Stock","Depto Ventas","Vel venta depto meses"],
        ["var_Casas Miles UF","Casas Stock","Casas Ventas","Vel venta casas meses"]]
    toolTip_mening=[
        ["Var Mes","Stock","Ventas","Vel. venta"],
        ["Var Mes","Stock","Ventas","Vel. venta"],
        ["Var Mes","Stock","Ventas","Vel. venta"]]

    jsonDir = DataToJson(df,varible_v,variable_meaning,reg_name, toolTip_v, toolTip_mening)
    jsonDir = [info_header,jsonDir ]  
    jsonUTF8 = json.dumps(jsonDir, ensure_ascii=False).encode('utf8')
    jsonUTF8 = json.loads(jsonUTF8)    
    create_image(df, varible_v[0], variable_meaning[0],naming_image(full_file_name))
    name_file = naming_file(full_file_name)
    with open(name_file , 'w') as outfile:  
        json.dump(jsonUTF8, outfile,ensure_ascii=False)
    print("CREATED: ", name_file)
# Out:
# set: None
# CREATED:  ./data/IH_04_venta_stgo.json

# %% [markdown]
# ### 5) IH_05_Ind_precios_stgo.json

# %%
sheetname = 'Ind_Precios_stgo'
full_file_name = '05_Ind_precios_stgo'
info_header[0]["titulo"]="Índice Real de Precios de Vivienda Santiago (%)"
info_header[0]["Fuente"]="IRPV, Índice Real de Precios de Vivienda, CChC"
info_header[0]["LinkDatosOriginales"]=link_data
info_header[0]["comment"]="Variaciones anuales de $ en % por zonas en Santiago y tipo de vivienda (Base 2004 = 100). Fuente CChC"
info_header[0]["linkPlot"] = link_img + init_data_name + full_file_name + ".png"
info_header[0]["glosario"]= ""

if sheetname=='Ind_Precios_stgo':
    df = pd.read_excel( file, sheet_name = sheetname)

    varible_v=[
    'Var % $ CASA Nor poniente',
    'Var % $ CASA Nor oriente',
    'Var % $ CASA Sur',
    'Var % $ DEPTO Santiago Centro',
    'Var % $ DEPTO Nor poniente',
    'Var % $ DEPTO Nor oriente',
    'Var % $ DEPTO Sur'
    ]

    variable_meaning=[
    'Var % $ CASA Nor poniente',
    'Var % $ CASA Nor oriente',
    'Var % $ CASA Sur',
    'Var % $ DEPTO Santiago Centro',
    'Var % $ DEPTO Nor poniente',
    'Var % $ DEPTO Nor oriente',
    'Var % $ DEPTO Sur'
    ]

    reg_name=[
    'Var % $ CASA NorPoniente',
    'Var % $ CASA NorOriente',
    'Var % $ CASA Sur',
    'Var % $ DEPTO Santiago Centro',
    'Var % $ DEPTO NorPoniente',
    'Var % $ DEPTO NorOriente',
    'Var % $ DEPTO Sur'
    ]

    toolTip_v=[
        ["Var % $ CASA"],
        ["Var % $ CASA"],
        ["Var % $ CASA"],
        ["Var % $ DPTO"],
        ["Var % $ DPTO"],
        ["Var % $ DPTO"],
        ["Var % $ DPTO"]]

    toolTip_mening=[
        ["Var CASA total"],
        ["Var CASA total"],
        ["Var CASA total"],
        ["Var Depto total"],
        ["Var Depto total"],
        ["Var Depto total"],
        ["Var Depto total"]]

    jsonDir = DataToJson(df,varible_v,variable_meaning,reg_name, toolTip_v, toolTip_mening)
    jsonDir = [info_header,jsonDir ]
    jsonUTF8 = json.dumps(jsonDir, ensure_ascii=False).encode('utf8')
    jsonUTF8 = json.loads(jsonUTF8)    
    create_image(df, varible_v[0], variable_meaning[0],naming_image(full_file_name))
    name_file = naming_file(full_file_name)
    with open(name_file , 'w') as outfile:  
        json.dump(jsonUTF8, outfile,ensure_ascii=False)
    print("CREATED: ", name_file)
# Out:
# set: None
# CREATED:  ./data/IH_05_Ind_precios_stgo.json

# %% [markdown]
# ### 6) IH_06_Hacinamiento.json viejo

# %%
sheetname = 'Hacinamiento'
full_file_name = '06_Hacinamiento'
regiones=['Arica y Parinacota','Tarapacá','Antofagasta','Atacama','Coquimbo','Valparaíso',
"O'Higgins",'Maule','Ñuble','Biobío','La Araucanía','Los Ríos',
'Los Lagos','Aysén','Magallanes','Metropolitana']
info_header[0]["titulo"] = "Grado de hacinamiento por Región"
info_header[0]["Fuente"] = "NENE del INE y SII"
info_header[0]["LinkDatosOriginales"] = link_data
info_header[0]["comment"] = "Grado de hacinamiento de las viviendas particulares ocupadas. Se considera 'Sin hacinamiento' Hogares con menos de 2,5 personas por dormitorio de uso exclusivo y 'Con hacinamiento' Hogares con 2,5 o más personas por dormitorio de uso exclusivo. Fuente: encuesta CASEN, Ministerio de Desarrollo Social y Familia"
info_header[0]["linkPlot"] = link_img + init_data_name + full_file_name + ".png"
info_header[0]["glosario"] = ""

if sheetname == 'Hacinamiento':
    byReg = {}
    df = pd.read_excel("casen.xlsx", sheet_name=sheetname)
    for val in regiones:
        ldf = df.query('Region == @val')
#        df[df['Region'] == val]
        varible_v = ["Hacinamiento","sin Hacinamiento"]
        variable_meaning = ["Hacinamiento","sin Hacinamiento"]
        reg_name = ["Hacinamiento","sin Hacinamiento"]
        toolTip_v = [["Var1"],["Var2"]]
        toolTip_mening = [["Var"],["Var"]]
       
        byReg[val] = DataToJson(ldf, varible_v, variable_meaning,reg_name, toolTip_v, toolTip_mening, norm)

    jsonDir = [info_header, byReg]
    jsonUTF8 = json.dumps(jsonDir, ensure_ascii=False).encode('utf8')
    jsonUTF8 = json.loads(jsonUTF8)    
    create_image(df, varible_v[0], variable_meaning[0],naming_image(full_file_name))
    name_file = naming_file(full_file_name)
    with open(name_file , 'w') as outfile:  
        json.dump(jsonUTF8, outfile,ensure_ascii=False)
    print("CREATED: ", name_file)
# Out:
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# CREATED:  ./data/IH_06_Hacinamiento.json

# %% [markdown]
# ### 7) IH_07_Materialidad.json

# %%
sheetname = 'Materialidad'
full_file_name = '07_Materialidad'
regiones=['Arica y Parinacota','Tarapacá','Antofagasta','Atacama','Coquimbo','Valparaíso',
"O'Higgins",'Maule','Ñuble','Biobio','La Araucanía','Los Ríos',
'Los Lagos','Aysén','Magallanes','Metropolitana']
info_header[0]["titulo"] = "Índice de materialidad de las viviendas por Región"
info_header[0]["Fuente"] = "NENE del INE y SII"
info_header[0]["LinkDatosOriginales"] = link_data
info_header[0]["comment"] = "Índice de materialidad de las viviendas responden a condiciones materiales de las viviendas utilizadas. Se construye a partir de los materiales predominantes en paredes exteriores, cubierta de techo y pisos. Establece categorías de Aceptable, Recuperable e Irrecuperable. Fuente: encuesta CASEN, Ministerio de Desarrollo Social y Familia"
info_header[0]["linkPlot"] = link_img + init_data_name + full_file_name + ".png"
info_header[0]["glosario"] = ""

if sheetname == 'Materialidad':
    df = pd.read_excel("casen.xlsx", sheet_name=sheetname)
    byReg = {}
    for val in regiones:
        ldf = df.query('Region == @val')
        varible_v = ["aceptable","recuperable","Irrecuperable"]
        variable_meaning = ["aceptable","recuperable","Irrecuperable"]
        reg_name = ["aceptable","recuperable","Irrecuperable"]
        toolTip_v = [["var1"],["var2"],["var3"]]
        toolTip_mening = [["Var"],["Var"],["Var"]]
    
        byReg[val] = DataToJson(ldf, varible_v, variable_meaning,reg_name, toolTip_v, toolTip_mening, norm)

    jsonDir = [info_header, byReg]
    jsonUTF8 = json.dumps(jsonDir, ensure_ascii=False).encode('utf8')
    jsonUTF8 = json.loads(jsonUTF8)    
    create_image(df, varible_v[0], variable_meaning[0],naming_image(full_file_name))
    name_file = naming_file(full_file_name)
    with open(name_file , 'w') as outfile:  
        json.dump(jsonUTF8, outfile,ensure_ascii=False)
    print("CREATED: ", name_file)
# Out:
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# CREATED:  ./data/IH_07_Materialidad.json

# %% [markdown]
# ### 8) IH_08_Conservacion.json

# %%
sheetname = 'Conservacion'
full_file_name = '08_Conservacion'
regiones=['Arica y Parinacota','Tarapacá','Antofagasta','Atacama','Coquimbo','Valparaíso',
"O'Higgins",'Maule','Ñuble','Biobío','La Araucanía','Los Ríos',
'Los Lagos','Aysén','Magallanes','Metropolitana']
info_header[0]["titulo"] = "índice del estado de conservación de las viviendas por Región"
info_header[0]["Fuente"] = "NENE del INE y SII"
info_header[0]["LinkDatosOriginales"] = link_data
info_header[0]["comment"] = "Índice de estado de conservación de las viviendas que considera el estado de conservación observados en muros, techos y pisos de la vivienda. Fuente: encuesta CASEN, Ministerio de Desarrollo Social y Familia"
info_header[0]["linkPlot"] = link_img + init_data_name + full_file_name + ".png"
info_header[0]["glosario"] = ""

if sheetname == 'Conservacion':
    df = pd.read_excel("casen.xlsx", sheet_name=sheetname)
    byReg = {}
    for val in regiones:
        ldf = df.query('Region == @val')
        varible_v = ["Bueno", "Regular", "Malo"]
        variable_meaning = ["Bueno", "Regular", "Malo"]
        reg_name = ["Bueno", "Regular", "Malo"]
        toolTip_v = [["var1"],["var2"],["var3"]]
        toolTip_mening = [["Var"],["Var"],["Var"]]
        
        byReg[val] = DataToJson(ldf, varible_v, variable_meaning,reg_name, toolTip_v, toolTip_mening, norm)
        
    jsonDir = [info_header, byReg]
    jsonUTF8 = json.dumps(jsonDir, ensure_ascii=False).encode('utf8')
    jsonUTF8 = json.loads(jsonUTF8)    
    create_image(df, varible_v[0], variable_meaning[0],naming_image(full_file_name))
    name_file = naming_file(full_file_name)
    with open(name_file , 'w') as outfile:  
        json.dump(jsonUTF8, outfile,ensure_ascii=False)
    print("CREATED: ", name_file)
# Out:
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# set: None
# CREATED:  ./data/IH_08_Conservacion.json
